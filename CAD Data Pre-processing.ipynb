# %% [markdown]
# # 2023 Call Data Pre-processing

# %%
import pandas as pd

pd.set_option("display.max_columns", None)

#reads csv; fixes comma, and quote issues.
df = pd.read_csv(
    # INSERT FILE PATHWAY HERE",
    sep=",",
    engine="python",
    dtype=str,
    quotechar='"',
    quoting=0,               
    on_bad_lines="warn"     
)


# Remove '(s)', which bigquery does not process. Rename columns.
df = df.rename(columns={
    "CAD Event Number" : "cad_event_number",
    "CAD Event Clearance Description" : "cad_event_clearance_description",
    "Call Type" : "call_type",
    "Priority" : "priority",
    "Initial Call Type" : "initial_call_type",
    "Final Call Type" : "final_call_type",
    "CAD Event Original Time Queued" : "cad_event_original_time_queued",
    "CAD Event Arrived Time" : "cad_event_arrived_time",
    "Dispatch Precinct" : "dispatch_precinct",
    "Dispatch Sector" : "dispatch_sector",
    "Dispatch Beat" : "dispatch_beat",
    "Dispatch Longitude" : "dispatch_longitude",
    "Dispatch Latitude" : "dispatch_latitude",
    "Dispatch Reporting Area" : "dispatch_reporting_area",
    "CAD Event Response Category" : "cad_event_response_category",
    "Call Sign Dispatch ID" : "call_sign_dispatch_id",
    "Call Sign Dispatch Time" : "call_sign_dispatch_time",
    "First SPD Call Sign Dispatch Time" : "first_spd_call_sign_dispatch_time",
    "Last SPD Call Sign In-Service Time" : "last_spd_call_sign_dispatch_time",
    "Call Sign Response Time (s)" : "call_sign_response_time_seconds",
    "Call Sign at Scene Time" : "call_sign_at_scene_time",
    "CAD Event First Response Time (s)" : "cad_event_first_response_time_seconds",
    "CARE Call Sign Total Service Time (s)" : "care_call_sign_total_service_time_in_seconds",
    "Co-Response Call Sign Total Service Time (s)" : "coresponse_call_sign_total_service_time_in_seconds",
    "SPD Call Sign Total Service Time (s)" : "spd_call_sign_total_service_time_in_seconds",
    "First SPD Call Sign Dispatch Delay Time (s)" : "first_spd_call_sign_dispatch_delay_time_in_seconds",
    "First SPD Call Sign Response Time (s)" : "first_spd_call_sign_response_time_in_seconds",
    "Call Sign Dispatch Delay Time (s)" : "call_sign_dispatch_delay_time_in_seconds",
    "Call Sign Total Service Time (s)" : "call_sign_total_service_time_in_seconds",
    "Call Sign In-Service Time" : "call_sign_inservice_time",
    "Call Type Indicator" : "call_type_indicator",
    "Dispatch Neighborhood" : "dispatch_neighborhood", 
    "Call Type Received Classification" : "call_type_received_classification",
    "Dispatch Address" : "dispatch_address",
    "Count Of Officers" : "count_of_officers",
    "First SPD Call Sign at Scene Time" : "first_spd_call_sign_at_scene_time"
})

# Checking column names are legal for SQL query
#for col in df.columns:
#    print(col)

# Write to Parquet
df.to_parquet(
    "/Users/meghinton/Desktop/Work & Career/Portfolio Projects/police_workload/Call_Data_2023_WEST.paraquet",
    engine="pyarrow",
    index=False
)
# Makes sure we didn't lose any records
print(df.shape)

# Show dataframe
df
# Out:
# (169260, 36)
#        cad_event_number           cad_event_clearance_description call_type  \
# 0         2023000231012                       ASSISTANCE RENDERED       911
# 1         2023000004345                REPORT WRITTEN (NO ARREST)       911
# 2         2023000009179                       ASSISTANCE RENDERED    ONVIEW
# 3         2023000203001                   PROBLEM SOLVING PROJECT    ONVIEW
# 4         2023000207805                      PHYSICAL ARREST MADE       911
# ...                 ...                                       ...       ...
# 169255    2023000338663  UNABLE TO LOCATE INCIDENT OR COMPLAINANT       911
# 169256    2023000342338                       ASSISTANCE RENDERED       911
# 169257    2023000347511    NO POLICE ACTION POSSIBLE OR NECESSARY       911
# 169258    2023000349758                REPORT WRITTEN (NO ARREST)    ONVIEW
# 169259    2023000360198    NO POLICE ACTION POSSIBLE OR NECESSARY    ONVIEW
#
# ...

# %% [markdown]
# # 2024 Call Data Pre-processing

# %%
import pandas as pd

pd.set_option("display.max_columns", None)

#reads csv; fixes comma, and quote issues.
df = pd.read_csv(
    # INSERT FILE PATHWAY HERE",
    sep=",",
    engine="python",
    dtype=str,
    quotechar='"',
    quoting=0,               
    on_bad_lines="warn"     
)

# Remove '(s)', which bigquery does not process. Rename columns.
df = df.rename(columns={
    "CAD Event Number" : "cad_event_number",
    "CAD Event Clearance Description" : "cad_event_clearance_description",
    "Call Type" : "call_type",
    "Priority" : "priority",
    "Initial Call Type" : "initial_call_type",
    "Final Call Type" : "final_call_type",
    "CAD Event Original Time Queued" : "cad_event_original_time_queued",
    "CAD Event Arrived Time" : "cad_event_arrived_time",
    "Dispatch Precinct" : "dispatch_precinct",
    "Dispatch Sector" : "dispatch_sector",
    "Dispatch Beat" : "dispatch_beat",
    "Dispatch Longitude" : "dispatch_longitude",
    "Dispatch Latitude" : "dispatch_latitude",
    "Dispatch Reporting Area" : "dispatch_reporting_area",
    "CAD Event Response Category" : "cad_event_response_category",
    "Call Sign Dispatch ID" : "call_sign_dispatch_id",
    "Call Sign Dispatch Time" : "call_sign_dispatch_time",
    "First SPD Call Sign Dispatch Time" : "first_spd_call_sign_dispatch_time",
    "Last SPD Call Sign In-Service Time" : "last_spd_call_sign_dispatch_time",
    "Call Sign Response Time (s)" : "call_sign_response_time_seconds",
    "Call Sign at Scene Time" : "call_sign_at_scene_time",
    "CAD Event First Response Time (s)" : "cad_event_first_response_time_seconds",
    "CARE Call Sign Total Service Time (s)" : "care_call_sign_total_service_time_in_seconds",
    "Co-Response Call Sign Total Service Time (s)" : "coresponse_call_sign_total_service_time_in_seconds",
    "SPD Call Sign Total Service Time (s)" : "spd_call_sign_total_service_time_in_seconds",
    "First SPD Call Sign Dispatch Delay Time (s)" : "first_spd_call_sign_dispatch_delay_time_in_seconds",
    "First SPD Call Sign Response Time (s)" : "first_spd_call_sign_response_time_in_seconds",
    "Call Sign Dispatch Delay Time (s)" : "call_sign_dispatch_delay_time_in_seconds",
    "Call Sign Total Service Time (s)" : "call_sign_total_service_time_in_seconds",
    "Call Sign In-Service Time" : "call_sign_inservice_time",
    "Call Type Indicator" : "call_type_indicator",
    "Dispatch Neighborhood" : "dispatch_neighborhood", 
    "Call Type Received Classification" : "call_type_received_classification",
    "Dispatch Address" : "dispatch_address",
    "Count Of Officers" : "count_of_officers",
    "First SPD Call Sign at Scene Time" : "first_spd_call_sign_at_scene_time"
})

# Write to Parquet
df.to_parquet(
    "/Users/meghinton/Desktop/Work & Career/Portfolio Projects/police_workload/Call_Data_2024_WEST.paraquet",
    engine="pyarrow",
    index=False
)
# Makes sure we didn't lose any records
print(df.shape)

# Show dataframe
df
# Out:
# (152602, 36)
#        cad_event_number           cad_event_clearance_description  \
# 0         2024000149560                       ASSISTANCE RENDERED
# 1         2024000153860                       ASSISTANCE RENDERED
# 2         2024000155738                REPORT WRITTEN (NO ARREST)
# 3         2024000168099                       ASSISTANCE RENDERED
# 4         2024000174111                       ASSISTANCE RENDERED
# ...                 ...                                       ...
# 152597    2024000297709                      PHYSICAL ARREST MADE
# 152598    2024000297739                                  CITATION
# 152599    2024000322894  UNABLE TO LOCATE INCIDENT OR COMPLAINANT
# 152600    2024000325072                       ASSISTANCE RENDERED
# 152601    2024000342303                       ASSISTANCE RENDERED
#
#                        call_type priority  \
# 0       TELEPHONE OTHER, NOT 911        1
# 1                            911        2
# ...

# %% [markdown]
# # 2025 Call Data Pre-Processing

# %%
import pandas as pd

pd.set_option("display.max_columns", None)

#reads csv; fixes comma, and quote issues.
df = pd.read_csv(
    # INSERT FILE PATHWAY HERE",
    sep=",",
    engine="python",
    dtype=str,
    quotechar='"',
    quoting=0,               
    on_bad_lines="warn"     
)

# Remove '(s)', which bigquery does not process. Rename columns.
df = df.rename(columns={
    "CAD Event Number" : "cad_event_number",
    "CAD Event Clearance Description" : "cad_event_clearance_description",
    "Call Type" : "call_type",
    "Priority" : "priority",
    "Initial Call Type" : "initial_call_type",
    "Final Call Type" : "final_call_type",
    "CAD Event Original Time Queued" : "cad_event_original_time_queued",
    "CAD Event Arrived Time" : "cad_event_arrived_time",
    "Dispatch Precinct" : "dispatch_precinct",
    "Dispatch Sector" : "dispatch_sector",
    "Dispatch Beat" : "dispatch_beat",
    "Dispatch Longitude" : "dispatch_longitude",
    "Dispatch Latitude" : "dispatch_latitude",
    "Dispatch Reporting Area" : "dispatch_reporting_area",
    "CAD Event Response Category" : "cad_event_response_category",
    "Call Sign Dispatch ID" : "call_sign_dispatch_id",
    "Call Sign Dispatch Time" : "call_sign_dispatch_time",
    "First SPD Call Sign Dispatch Time" : "first_spd_call_sign_dispatch_time",
    "Last SPD Call Sign In-Service Time" : "last_spd_call_sign_dispatch_time",
    "Call Sign Response Time (s)" : "call_sign_response_time_seconds",
    "Call Sign at Scene Time" : "call_sign_at_scene_time",
    "CAD Event First Response Time (s)" : "cad_event_first_response_time_seconds",
    "CARE Call Sign Total Service Time (s)" : "care_call_sign_total_service_time_in_seconds",
    "Co-Response Call Sign Total Service Time (s)" : "coresponse_call_sign_total_service_time_in_seconds",
    "SPD Call Sign Total Service Time (s)" : "spd_call_sign_total_service_time_in_seconds",
    "First SPD Call Sign Dispatch Delay Time (s)" : "first_spd_call_sign_dispatch_delay_time_in_seconds",
    "First SPD Call Sign Response Time (s)" : "first_spd_call_sign_response_time_in_seconds",
    "Call Sign Dispatch Delay Time (s)" : "call_sign_dispatch_delay_time_in_seconds",
    "Call Sign Total Service Time (s)" : "call_sign_total_service_time_in_seconds",
    "Call Sign In-Service Time" : "call_sign_inservice_time",
    "Call Type Indicator" : "call_type_indicator",
    "Dispatch Neighborhood" : "dispatch_neighborhood", 
    "Call Type Received Classification" : "call_type_received_classification",
    "Dispatch Address" : "dispatch_address",
    "Count Of Officers" : "count_of_officers",
    "First SPD Call Sign at Scene Time" : "first_spd_call_sign_at_scene_time"
})

# Write to Parquet
df.to_parquet(
    "/Users/meghinton/Desktop/Work & Career/Portfolio Projects/police_workload/Call_Data_2025_WEST.paraquet",
    engine="pyarrow",
    index=False
)
# Makes sure we didn't lose any records
print(df.shape)

# Show dataframe
df
# Out:
# (147776, 36)
#        cad_event_number         cad_event_clearance_description  \
# 0         2025000117297               RADIO BROADCAST AND CLEAR
# 1         2025000157268                     ASSISTANCE RENDERED
# 2         2025000096077              REPORT WRITTEN (NO ARREST)
# 3         2025000116460  NO POLICE ACTION POSSIBLE OR NECESSARY
# 4         2025000119001                     ASSISTANCE RENDERED
# ...                 ...                                     ...
# 147771    2025000364204                    PHYSICAL ARREST MADE
# 147772    2025000370783                     ASSISTANCE RENDERED
# 147773    2025000372839              REPORT WRITTEN (NO ARREST)
# 147774    2025000381472                     ASSISTANCE RENDERED
# 147775    2025000381589                       OTHER REPORT MADE
#
#                        call_type priority  \
# 0                         ONVIEW        4
# 1       TELEPHONE OTHER, NOT 911        3
# 2                         ONVIEW        7
# ...
